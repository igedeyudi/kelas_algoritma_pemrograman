# %% [markdown]
# <h1 style="color: #fff; background: #142d4c; padding: 10px; border-radius:10px"> Latihan Pertemuan 3 </h1>
#
# **Author: Bakhtiar Amaludin, I Gede Yudi Paramartha, Widya Pranayoga**

# %% [markdown]
# <h2 style="color: #142d4c; background: #9fd3c7; padding: 10px; border-radius:10px"> Fungsi dan Iterasi</h2>

# %% [markdown]
# <h3 style="color: #142d4c; background: #ececec; padding: 10px; border-radius:10px"> Mask </h3>
#
# Buat sebuah fungsi untuk menyamarkan sebuah nilai (baik string maupun int) menjadi masked value dengan karakter tertentu.
#
# Input Fungsi:
# * data: data yang akan di masked
# * karakter : karakter untuk masking, default adalah *
#
# Test:
# Dari 1236325 menjadi *******
#
# Dari 'A92BE' menjadi =====

# %%
## Jawaban

# %% [markdown]
# <h3 style="color: #142d4c; background: #ececec; padding: 10px; border-radius:10px"> Jumlah Bilangan </h3>
#
# Buat sebuah fungsi untuk menghitung jumlah bilangan dari 1 sampai bilangan ke n
# Contoh 1+2+3....n:

# %%
# Jawaban

# %% [markdown]
# <h3 style="color: #142d4c; background: #ececec; padding: 10px; border-radius:10px"> Piket Pegawai </h3>
#
# Pada sebuah kantor terdapat tiga orang pegawai bernama Adi, Budi, dan Charlie.
# Mereka bersepakat untuk melakukan piket secara bergantian melakukan tugas untuk berjaga di ruang
# layanan informasi di kantornya. Setiap orang secara berurutan akan bergantian berjaga setiap
# harinya. Jika sudah mencapai orang keenam maka akan kembali ke orang pertama.
#
# Buat sebuah fungsi untuk mengetahui nama orang yang akan berjaga pada hari ke n.
# Hari tidak boleh bernilai negatif.

# %%
# Jawaban

# %% [markdown]
# <h3 style="color: #142d4c; background: #ececec; padding: 10px; border-radius:10px"> Tarif Pajak </h3>
#
# Buat sebuah fungsi untuk menghitung PPh Pasal 17.
# Diambil dari https://ortax.org/mengenal-tarif-pph-pasal-17-dalam-menghitung-pph-21.
#
# Andreas bekerja pada PT Ortax Indonesia. Diketahui bahwa Andreas memiliki Penghasilan Kena Pajak (PKP) sebesar Rp560 juta. Berikut PPh Pasal 21 terutang Mr. Andreas jika menggunakan UU HPP.
#
# ![image.png](attachment:9f383f45-abbd-4161-800f-82e119284c5c.png)
#
# ![image.png](attachment:46c510e8-cb25-47d0-8e48-1c612597f66b.png)
#
# Input Fungsi: PKP dalam jutaan rupiah (float), PKP > 0

# %%
# Jawaban (tanpa menggunakan list)
def pajak(pkp):
    return 

pajak(560)
